# %%
#Libraries
import numpy as np
import matplotlib.pyplot as plt
import h5py
import os
import seaborn as sns
import matplotlib.cm as cm
import matplotlib.colors as mcolors

from astropy.cosmology import FlatLambdaCDM # https://docs.astropy.org/en/stable/cosmology/index.html
cosmo = FlatLambdaCDM(H0=70, Om0=0.3) # define the cosmology to be used in this script
Lum_r_sun = 0.15 # times the solar luminosity. I computed using the r-band effective values: lamba = 6180 A and Delta lambda = 1200 A

plt.style.use("nick_style")

def available_outputs() -> list:
    # Get the list of items in the current directory
    items = sorted(os.listdir('./output'))

    # Print a header for clarity
    print("Available output directories:\n" + "-"*75)

    # Print each item on a new line
    for idx, item in enumerate(items, start=1):
        print(f"{idx}. {item}")
    print("-"*75)

    return items

avail_files = available_outputs()
# Out:
# Available output directories:
# ---------------------------------------------------------------------------
# 1. mfLeja_sfLeja_chsharma-like_mnn_WSFR_N10000_n5_sduniform-vol_nzbins100_mladvanced_MLgrnoextrp_kTrue_0
# 2. mfLeja_sfLeja_chsharma-like_mnn_WSFR_N10000_n5_sduniform-vol_nzbins100_mladvanced_allblue_kTrue_0
# 3. mfLeja_sfLeja_chsharma-like_mnn_WSFR_N10000_n5_sduniform-vol_nzbins100_mladvanced_allred_kTrue_0
# 4. mfLeja_sfLeja_chsharma-like_mnn_WSFR_N10000_n5_sduniform-vol_nzbins100_mladvanced_bimodalgr_kTrue_0
# 5. mfLeja_sfLeja_chsharma-like_mnn_WSFR_N10000_n5_sduniform-vol_nzbins100_mladvanced_bimodalgr_kTrue_1
# 6. mfLeja_sfLeja_chsharma-like_mnn_WSFR_N10000_n5_sduniform-vol_nzbins100_mladvanced_kTrue_0
# 7. mfLeja_sfLeja_chsharma-like_mnn_WSFR_N10000_n5_sduniform-vol_nzbins100_mladvanced_kTrue_1
# 8. mfLeja_sfLeja_chsharma-like_mnn_WSFR_N10000_n5_sduniform-vol_nzbins100_mladvanced_kTrue_2
# 9. mfLeja_sfLeja_chsharma-like_mnn_WSFR_N10000_n5_sduniform-vol_nzbins100_mladvanced_kTrue_3
# 10. mfLeja_sfLeja_chsharma-like_mnn_WSFR_N10000_n5_sduniform-vol_nzbins100_mladvanced_kTrue_4
# 11. mfLeja_sfLeja_chsharma-like_mnn_WSFR_N10000_n5_sduniform-vol_nzbins100_mladvanced_kTrue_5
# 12. mfLeja_sfLeja_chsharma-like_mnn_WSFR_N10000_n5_sduniform-vol_nzbins100_mladvanced_newbimodalgr_kTrue_0
# 13. mfLeja_sfLeja_chsharma-like_mnn_WSFR_N20000_n10_sduniform-vol_nzbins20_mladvanced_zrange0.0to1.2_kTrue_0
# 14. mfLeja_sfLeja_chsharma-like_mnn_WSFR_N20000_n20_sddelta_at_zright__mladvanced_zrange0.0to1.2_zgallength120_kTrue_0
# 15. mfLeja_sfLeja_chsharma-like_mnn_Wmass_N10000_n5_sduniform-vol_nzbins100_mladvanced_bimodalgr_kTrue_0
# 16. mfLeja_sfLeja_chsharma-like_mnn_Wmass_N10000_n5_sduniform-vol_nzbins100_mladvanced_kTrue_0
# 17. mfLeja_sfLeja_chsharma-like_mnn_Wmass_N20000_n10_sduniform-vol_nzbins20_mladvanced_zrange0.0to1.2_kTrue_0
# 18. mfLeja_sfLeja_chsharma-like_mnn_Wmass_N20000_n20_sddelta_at_zright__mladvanced_zrange0.0to1.2_zgallength120_kTrue_0
# ---------------------------------------------------------------------------

# %%
def print_available_information(fname: str) -> None:
    # Check if the file exists
    file_path = './output/' + fname + '/dataset.h5'
    if not os.path.exists(file_path):
        print(f"File '{file_path}' does not exist.")
        return

    # Check if the dataset is a group
    with h5py.File(file_path, 'r') as hf:
        if not isinstance(hf, h5py.Group):
            print(f"Dataset '{file_path}' is not a group.")
            return

        # Print the available information
        print("Available information stored in the .h5 file:\n" + "-"*75)

        # Get the names of the various datasets stored in the .h5 file
        other_datasets = list(hf.keys())

        # Get the attributes of the .h5 file
        attributes = hf.attrs

        # Print the names of the datasets
        for dataset in other_datasets:
            print(dataset)
        print("-"*75)

        # Print the attributes
        print("Attributes of the .h5 file:\n" + "-"*75)
        for attribute in attributes:
            print(attribute + ": " + str(attributes[attribute]))
        print("-"*75)

print_available_information(fname=avail_files[2])
# Out:
# Available information stored in the .h5 file:
# ---------------------------------------------------------------------------
# Kcorr_samples
# MtoL_samples
# MtoLg_rest_samples
# color_gr_grid
# color_samples
# density_sfr_color
# lgsfr_mode_samples
# lgsfr_samples
# logm_samples
# magcut_ind_flags
# redshift_samples
# sfr_grid
# ---------------------------------------------------------------------------
# Attributes of the .h5 file:
# ---------------------------------------------------------------------------
# Kr_correction: True
# Nsample: 10000
# completeness_handling: sharma-like
# data_source: Sharma_full
# description: Output was created on 2025-06-20.
# dz: 0.1
# mfunc_mstar0: 100000.0
# mfunc_ref: Leja
# mfunc_slope: 0
# ml_sampling: advanced
# mmax: 12.5
# mmin: 6.5
# mode: nn
# n_realizations: 5
# ndummy: 31
# nlogm: 120
# nsfr: 120
# nz_bins: 100
# posterior: True
# sfr_ref: Leja
# sfr_sampling: True
# sfrmax: 3.0
# sfrmin: -3.0
# sigma_norm: 12.0
# space_dist: uniform-vol
# weight: SFR
# zbins: [0.  0.2 0.4 0.7]
# zgal: [0.1  0.3  0.55]
# zmax: 1.2
# zmin: 0.2
# ---------------------------------------------------------------------------

# %%
def load_data(fname: str='specify_output_directory') :
    # Load the data
    with h5py.File('./output/'+ fname +'/dataset.h5', 'r') as hf :
        logm_samples = np.array(hf['logm_samples']) # log10(M/Msun)
        magcut_ind_samples = np.array(hf['magcut_ind_flags']) # Magnitude cut flags
        n_realizations = hf.attrs['n_realizations'] # Number of realizations per redshift bin
        zgal = hf.attrs['zgal']
        zbins = hf.attrs['zbins']
    return logm_samples, magcut_ind_samples, n_realizations, zgal, zbins

# %%
def plot_cdfs(fnames: list = [], 
              tags: list = [],
              zgal: list = [0.1, 0.3, 0.55],
              zbins: list = [0., 0.2, 0.4, 0.7],
              color_palette: str = 'husl',
              clrs: list = None,
              plot_raw: bool = True,
              lw_raw: float = 2.,
              plot_mcut: bool = True,
              lw_mcut: float = 2.,
              caption_ncol: int = 3,
              savefig: bool = False, 
              fname: str = '_.pdf',
              xrange: tuple = (6.9,12.1),
              yrange: tuple = (0.,1.)
              ) -> None:
    
    Mr_sun = 4.65 #absolute magnitude of sun in r-band
    Lum_r_sun = 0.15 # times the solar luminosity. I computed using the r-band effective values: lamba = 6180 A and Delta lambda = 1200 A

    print(f"Plotting CDFs for {len(fnames)} models.")


    # create figure frame
    plt.subplots(1,len(zgal), figsize=(11,5), sharey=True, gridspec_kw={'wspace': 0, 'hspace': 0})
    plt.subplot(101+10*len(zgal))
    plt.ylabel('CDF')

    n_models = len(fnames)
    mbins = np.linspace(6.4, 12.6, 200) # cdf resolution in mass
    if clrs == None : clrs = sns.color_palette(n_colors=n_models+0, palette = color_palette)#[::-1]
    # iterate over all different run examples
    for k in range(len(fnames)):
        print(fnames[k], tags[k], clrs[k])
        with h5py.File('./output/'+ fnames[k] +'/dataset.h5', 'r') as hf :
            logm_samples = np.array(hf['logm_samples'])
            magcut_ind_samples = np.array(hf['magcut_ind_flags'])
            MtoL_samples = np.array(hf['MtoL_samples'])
            Kcorr_samples = np.array(hf['Kcorr_samples'])

            n_r = hf.attrs['n_realizations']
            tag = f"MF={hf.attrs['mfunc_ref']}, SF={hf.attrs['sfr_ref']}_{hf.attrs['mode']}, " +\
            f"W={hf.attrs['weight']}, sp.dist={hf.attrs['space_dist']}, M/L={hf.attrs['ml_sampling']}" # , sl={hf.attrs['mfunc_slope']}, $\sigma$={hf.attrs['sigma_norm']}
            try :
                if len(tags) > 0 : tag = tags[k]
            except :
                pass 
        for j in range(len(zgal)) :
            # plot raw predictions (no selection critertia were implemented)
            plt.subplot(101 + 10*len(zgal) + j)
            logm_zj = logm_samples[j*n_r:(j+1)*n_r].ravel()
            if plot_raw : plt.hist(logm_zj, cumulative=True, density=True, histtype='step', ls='--', color=clrs[k], bins=mbins, lw=lw_raw, alpha=0.8)
             
            # plot predictions including k-correction and magnitude cut 
            magcut_zj = magcut_ind_samples[j*n_r:(j+1)*n_r].ravel()
            logm_mc = logm_zj[magcut_zj]        
            if plot_mcut : 
                plt.hist(logm_mc, cumulative=True, density=True, histtype='step', ls='-', color=clrs[k], bins=mbins, lw=lw_mcut, alpha=0.8)#, label=tag)
                

            plt.title(f"{zbins[j]} $< z \leq$ {zbins[j+1]}")
            plt.xlabel("$\mathrm{\log M_\star ~ [M_\odot]}$"); 
            plt.xlim(xrange); plt.ylim(yrange)

    plt.subplot(132)
    plt.legend(fontsize=12, loc='lower center', bbox_to_anchor=(0.5, -0.3), ncol=caption_ncol)

    #plt.subplot(333)
    #plt.text(12.6, 0.5, s='no selection criterion\nno Kr-correction', color='gray', rotation=-90, ma='center', va='center', fontsize=16)
    
    #plt.subplot(336)
    #plt.text(12.6, 0.5, s='$\mathrm{rmag < 23.5}$\nno Kr-correction', color='gray', rotation=-90, ma='center', va='center', fontsize=16)
    #plt.subplot(339)
    #plt.text(12.6, 0.5, s='$\mathrm{rmag < 23.5}$\nwith Kr-correction', color='gray', rotation=-90, ma='center', va='center', fontsize=16)
    plt.tight_layout()
    #plt.subplots_adjust(bottom=-0.2)
    plt.show()

# %%
plot_cdfs(fnames = [avail_files[8], avail_files[15]][::-1],
tags = ['single Schechter mass-function', 'Two-component Schechter (Leja)'][::-1], 
plot_raw=False, caption_ncol=4, color_palette='tab10', clrs=['blue', 'red'])
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Plotting CDFs for 2 models.
# mfLeja_sfLeja_chsharma-like_mnn_Wmass_N10000_n5_sduniform-vol_nzbins100_mladvanced_kTrue_0 Two-component Schechter (Leja) blue
# mfLeja_sfLeja_chsharma-like_mnn_WSFR_N10000_n5_sduniform-vol_nzbins100_mladvanced_kTrue_3 single Schechter mass-function red

# %%
def create_mixed_stellar_mass_distr(fnames: list = [], 
              tags: list = [],
              zgal: list = [0.1, 0.3, 0.55],
              zbins: list = [0., 0.2, 0.4, 0.7],
              mmin: float = 6.5,
              mmax: float = 12.5,
              mbins: int = 200,
              n_chi: int = 101,
              color_palette: str = 'husl',
              clrs: list = None,
              plot_raw: bool = True,
              lw_raw: float = 2.,
              plot_mcut: bool = True,
              lw_mcut: float = 2.,
              caption_ncol: int = 3,
              savefig: bool = False, 
              xrange: tuple = (6.9,12.1),
              yrange: tuple = (0.,1.), 
              save_mixed_distr: bool = True
              ) -> None:
    
    print(f"Using the following {len(fnames)} populations to generate mixed distributions.")
    print("SFR population:", fnames[0])
    print("Mass population:", fnames[1])
    fname_sfr = fnames[0]
    fname_mass = fnames[1]
    chi_bins = np.linspace(0., 1., n_chi) # resolution in the mixing parameter chi
    mbins = np.linspace(mmin, mmax, mbins) # cdf resolution in mass
    cmap = cm.get_cmap(color_palette)
    norm = mcolors.Normalize(vmin=chi_bins.min(), vmax=chi_bins.max())
    #if tags == [] : tags = [f"$\chi$={chi:.2f}" for chi in chi_bins]


    # load sfr-weighted data
    logm_sfr_pop = []; idc_sfr_pop = [];
    with h5py.File('./output/'+ fname_sfr +'/dataset.h5', 'r') as hf :
        logm_samples = np.array(hf['logm_samples'])
        magcut_ind_samples = np.array(hf['magcut_ind_flags'])
        n_r = hf.attrs['n_realizations']
        for j in range(len(zgal)) :
            tmp_mass_arr = logm_samples[j*n_r:(j+1)*n_r].ravel()
            tmp_idc_arr = magcut_ind_samples[j*n_r:(j+1)*n_r].ravel()
            shuffle_ind = np.random.permutation(len(tmp_mass_arr))
            logm_sfr_pop.append(tmp_mass_arr[shuffle_ind])
            idc_sfr_pop.append(tmp_idc_arr[shuffle_ind])  
            del tmp_mass_arr, tmp_idc_arr, shuffle_ind  

    # load mass-weighted data
    logm_mass_pop = []; idc_mass_pop = [];
    with h5py.File('./output/'+ fname_mass +'/dataset.h5', 'r') as hf :
        logm_samples = np.array(hf['logm_samples'])
        magcut_ind_samples = np.array(hf['magcut_ind_flags'])
        n_r = hf.attrs['n_realizations']
        for j in range(len(zgal)) :
            tmp_mass_arr = logm_samples[j*n_r:(j+1)*n_r].ravel()
            tmp_idc_arr = magcut_ind_samples[j*n_r:(j+1)*n_r].ravel()
            shuffle_ind = np.random.permutation(len(tmp_mass_arr))
            logm_mass_pop.append(tmp_mass_arr[shuffle_ind])
            idc_mass_pop.append(tmp_idc_arr[shuffle_ind]) 
            del tmp_mass_arr, tmp_idc_arr, shuffle_ind  


    # create figure frame
    plt.subplots(1,len(zgal), figsize=(11,5), sharey=True, gridspec_kw={'wspace': 0, 'hspace': 0})
    plt.subplot(101+10*len(zgal))
    plt.ylabel('CDF')

    for k, chi in enumerate(chi_bins) :

        print(f"Working with chi = {chi:.2f}")
        # create mixed population by randomly sampling from the two populations according to the mixing parameter chi
        n_sample = len(logm_sfr_pop[0])
        print(f"Total number of samples in each population: {n_sample}")
        n_sfr = int(chi * n_sample)
        n_mass = n_sample - n_sfr
        pop_sfr_ind = np.random.choice(n_sample, size=n_sfr, replace=False)
        pop_mass_ind = np.random.choice(n_sample, size=n_mass, replace=False)

        fname_chi = f"stellar_mass_distr_chi_{chi:.2f}.h5"

        # create all chi populations and store the mass distributions in an .h5 file
        with h5py.File('p_mass_dists/' + f"{fname_chi}" if save_mixed_distr else "p_mass_dists/tmp.h5" , 'w') as hf_out:
        

            computed_dists_with_mcut = np.zeros((len(zgal), len(mbins)-1))
            computed_dists = np.zeros((len(zgal), len(mbins)-1))


            for j in range(len(zgal)) :

                tmp_sfr_pop = logm_sfr_pop[j][pop_sfr_ind]
                tmp_sfr_pop_mcut = idc_sfr_pop[j][pop_sfr_ind]
                tmp_mass_pop = logm_mass_pop[j][pop_mass_ind]
                tmp_mass_pop_mcut = idc_mass_pop[j][pop_mass_ind]
                if n_sfr > 0 and n_mass > 0 : 
                    tmp_pop = np.concatenate([tmp_sfr_pop, tmp_mass_pop])
                    tmp_pop_ind = np.concatenate([tmp_sfr_pop_mcut, tmp_mass_pop_mcut])
                elif n_sfr==0 : 
                    tmp_pop = tmp_mass_pop; tmp_pop_ind = tmp_mass_pop_mcut
                elif n_mass == 0 :
                    tmp_pop = tmp_sfr_pop; tmp_pop_ind = tmp_sfr_pop_mcut

                # plot raw predictions (no selection critertia were implemented)
                plt.subplot(101 + 10*len(zgal) + j)
                tmp_pmass, massedges = np.histogram(tmp_pop, density=True, bins=mbins)
                tmp_cum_pmass = np.cumsum(tmp_pmass*np.diff(massedges))
                plt.plot((massedges[1:] + massedges[:-1])/2., tmp_cum_pmass, ls='--', marker='', color=cmap(norm(chi)), lw=lw_raw, alpha=0.8)
                
                # store raw mass distribution
                computed_dists[j,:] = np.copy(tmp_cum_pmass)
                
                # plot predictions including magnitude cut 
                logm_mc = tmp_pop[tmp_pop_ind]        
                tmp_pmass, massedges = np.histogram(logm_mc, density=True, bins=mbins)
                tmp_cum_pmass = np.cumsum(tmp_pmass*np.diff(massedges))
                plt.plot((massedges[1:] + massedges[:-1])/2., tmp_cum_pmass, ls='-', marker='', color=cmap(norm(chi)), lw=lw_mcut, alpha=0.8)#, label=tags[k])
                # store mass distribution after mag cut
                computed_dists_with_mcut[j,:] = np.copy(tmp_cum_pmass)
                

                if k==0 : 
                    plt.title(f"{zbins[j]} $< z \leq$ {zbins[j+1]}")
                    plt.xlabel("$\mathrm{\log M_\star ~ [M_\odot]}$"); 
                    plt.xlim(xrange); plt.ylim(yrange)

            hf_out.create_dataset('mass_bin_edges', data=massedges)
            hf_out.create_dataset('z_bins', data=zbins)
            hf_out.create_dataset('p_mass_distr_raw', data=computed_dists)
            hf_out.create_dataset('p_mass_distr_magcut', data=computed_dists_with_mcut)
            hf_out.attrs['chi'] = chi

            print(f"p(mass|population, chi={chi:.2f}) distribution stored successfully in 'p_mass_dists/{fname_chi}'")

    #plt.subplot(132)
    #plt.legend(fontsize=12, loc='lower center', bbox_to_anchor=(0.5, -0.3), ncol=caption_ncol)
    plt.subplot(133)
    sm = cm.ScalarMappable(cmap=cmap, norm=norm)
    sm.set_array([])
    cbar = plt.colorbar(sm, ax=plt.gca().axes, pad=0.005)
    cbar.set_label(r'$\rm \chi_{SFR}$', fontsize=14)

    plt.tight_layout()
    plt.show()

# %%
create_mixed_stellar_mass_distr(fnames = [avail_files[8], avail_files[15]], n_chi = 11, save_mixed_distr=False,
plot_raw=False, caption_ncol=4, color_palette='viridis',)
# Out:
# Using the following 2 populations to generate mixed distributions.
# SFR population: mfLeja_sfLeja_chsharma-like_mnn_WSFR_N10000_n5_sduniform-vol_nzbins100_mladvanced_kTrue_3
# Mass population: mfLeja_sfLeja_chsharma-like_mnn_Wmass_N10000_n5_sduniform-vol_nzbins100_mladvanced_kTrue_0
# Working with chi = 0.00
# Total number of samples in each population: 50000
# p(mass|population, chi=0.00) distribution stored successfully in 'p_mass_dists/stellar_mass_distr_chi_0.00.h5'
# Working with chi = 0.10
# Total number of samples in each population: 50000
# p(mass|population, chi=0.10) distribution stored successfully in 'p_mass_dists/stellar_mass_distr_chi_0.10.h5'
# Working with chi = 0.20
# Total number of samples in each population: 50000
# p(mass|population, chi=0.20) distribution stored successfully in 'p_mass_dists/stellar_mass_distr_chi_0.20.h5'
# Working with chi = 0.30
# Total number of samples in each population: 50000
# p(mass|population, chi=0.30) distribution stored successfully in 'p_mass_dists/stellar_mass_distr_chi_0.30.h5'
# Working with chi = 0.40
# Total number of samples in each population: 50000
# p(mass|population, chi=0.40) distribution stored successfully in 'p_mass_dists/stellar_mass_distr_chi_0.40.h5'
# Working with chi = 0.50
# Total number of samples in each population: 50000
# p(mass|population, chi=0.50) distribution stored successfully in 'p_mass_dists/stellar_mass_distr_chi_0.50.h5'
# Working with chi = 0.60
# Total number of samples in each population: 50000
# p(mass|population, chi=0.60) distribution stored successfully in 'p_mass_dists/stellar_mass_distr_chi_0.60.h5'
# Working with chi = 0.70
# Total number of samples in each population: 50000
# p(mass|population, chi=0.70) distribution stored successfully in 'p_mass_dists/stellar_mass_distr_chi_0.70.h5'
# Working with chi = 0.80
# Total number of samples in each population: 50000
# p(mass|population, chi=0.80) distribution stored successfully in 'p_mass_dists/stellar_mass_distr_chi_0.80.h5'
# Working with chi = 0.90
# Total number of samples in each population: 50000
# p(mass|population, chi=0.90) distribution stored successfully in 'p_mass_dists/stellar_mass_distr_chi_0.90.h5'
# Working with chi = 1.00
# Total number of samples in each population: 50000
# p(mass|population, chi=1.00) distribution stored successfully in 'p_mass_dists/stellar_mass_distr_chi_1.00.h5'
# /var/folders/g9/dk3cpkq96sq2w6xqb_xpvm6m0000gq/T/ipykernel_17427/3238298147.py:29: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap(color_palette)

# %% [markdown]
# ### Test the structure of the stored distributions

# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt

fname = 'stella_mass_distr.h5'
out_dir = 'p_mass_dists/'

with h5py.File(out_dir + fname, 'r') as hf:
    cdfmass_mass_weighted_with_mcut = hf['p_mass_distr_magcut'][0,:,:]
    cdfmass_sfr_weighted_with_mcut = hf['p_mass_distr_magcut'][1,:,:]
    cdfmass_mass_weighted_raw = hf['p_mass_distr_raw'][0,:,:]
    cdfmass_sfr_weighted_raw = hf['p_mass_distr_raw'][1,:,:]
    massedges = hf['mass_bin_edges'][:]
    zbins = hf['z_bins'][:]

# %%
def test_stored_data(fname: str = 'stella_mass_distr.h5',):

    nz = cdfmass_sfr_weighted_with_mcut.shape[0]
    clrs = ['blue', 'red']; xrange = (6.9,12.1); yrange = (0.,1.); caption_ncol=2
    # create figure frame
    plt.subplots(1,nz, figsize=(11,5), sharey=True, gridspec_kw={'wspace': 0, 'hspace': 0})
    
    # plot raw predictions (no selection critertia were implemented)
    for j in range(nz) :
        plt.subplot(101 + 10*nz + j)

        plt.plot((massedges[1:] + massedges[:-1])/2., cdfmass_mass_weighted_with_mcut[j], ls='-', marker='', color=clrs[0], lw=2, alpha=0.8, label='mass-weighted')
        plt.plot((massedges[1:] + massedges[:-1])/2., cdfmass_sfr_weighted_with_mcut[j], ls='-', marker='', color=clrs[1], lw=2, alpha=0.8, label='sfr-weighted')

        plt.plot((massedges[1:] + massedges[:-1])/2., cdfmass_mass_weighted_raw[j], ls='--', marker='', color=clrs[0], lw=1.5, alpha=0.8)
        plt.plot((massedges[1:] + massedges[:-1])/2., cdfmass_sfr_weighted_raw[j], ls='--', marker='', color=clrs[1], lw=1.5, alpha=0.8)


        plt.title(f"{zbins[j]} $< z \leq$ {zbins[j+1]}")
        plt.xlabel("$\mathrm{\log M_\star ~ [M_\odot]}$"); 
        plt.xlim(xrange); plt.ylim(yrange)

    plt.subplot(132)
    plt.legend(fontsize=12, loc='lower center', bbox_to_anchor=(0.5, -0.3), ncol=caption_ncol)
    plt.subplot(101+10*nz)
    plt.ylabel('CDF')
    plt.tight_layout()
    plt.show()

# %%
test_stored_data(fname='stella_mass_distr.h5')
